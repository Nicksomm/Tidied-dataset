# %% [markdown]
# Raw Dataset showing how Ohio counties voted in 2016 and 2020

# %%
import pandas as pd

# %%
df.head(10)
# Out:
#        County     Margin 2016 margin Est. votes reported  Unnamed: 4  \
# 0    Franklin  Biden +31      D+25.8                100%         NaN
# 1    Cuyahoga  Biden +34      D+35.2                100%         NaN
# 2    Hamilton  Biden +16      D+10.3                100%         NaN
# 3      Summit  Biden +10       D+8.5                100%         NaN
# 4  Montgomery   Biden +2       R+0.7                100%         NaN
# 5       Lucas  Biden +17      D+17.7                100%         NaN
# 6       Stark  Trump +19      R+17.2                100%         NaN
# 7      Butler  Trump +24      R+27.6                100%         NaN
# 8      Lorain   Trump +2       D+0.1                100%         NaN
# 9      Warren  Trump +31      R+37.1                100%         NaN
#
#   Total votes Absentee
# 0     630,577        —
# 1     625,670  584,988
# 2     430,929  245,471
# 3     280,473  149,069
# 4     268,505  154,486
# 5     200,623        —
# 6     189,879        —
# ...

# %%
df = pd.read_csv("Countyvotesraw.csv")
df.tail(10)
# Out:
#       County     Margin 2016 margin Est. votes reported  Unnamed: 4  \
# 78      Pike  Trump +49      R+36.5                100%         NaN
# 79     Adams  Trump +64      R+55.5                100%         NaN
# 80   Wyandot  Trump +50      R+46.6                100%         NaN
# 81     Meigs  Trump +53      R+50.3                100%         NaN
# 82  Paulding  Trump +51      R+48.5                100%         NaN
# 83  Harrison  Trump +53        R+48                100%         NaN
# 84    Monroe  Trump +54      R+46.8                100%         NaN
# 85    Morgan  Trump +48      R+41.6                100%         NaN
# 86     Noble  Trump +63      R+55.1                100%         NaN
# 87    Vinton  Trump +55      R+45.7                100%         NaN
#
#    Total votes Absentee
# 78      12,412        —
# 79      12,145        —
# 80      11,390        —
# 81      10,951    6,386
# 82       9,467    5,735
# 83       7,655        —
# 84       7,148        —
# ...

# %% [markdown]
# https://docs.google.com/spreadsheets/d/17Zu-_KbkyiVTJcO1kp5rcvnh33GElxEIeyet80fvxLQ/edit#gid=0

# %%
df.shape
# Out:
# (88, 7)

# %% [markdown]
# https://docs.google.com/spreadsheets/d/1iSYR9FXFGz9-97fKEkhA4aUARrnmODSI5dli6PlXM3Q/edit#gid=0

# %%
df = pd.read_csv("Countyvotestidied.csv")
df.head(10)
# Out:
#      Cuyahoga   Biden +34  D+35.2 Est. votes reported Total votes Absentee
# 0      Summit   Biden +10   D+8.5                100%     625,670  584,988
# 1  Montgomery    Biden +2   R+0.7                100%     430,929  245,471
# 2       Lucas   Biden +17  D+17.7                100%     280,473  149,069
# 3       Stark   Trump +19  R+17.2                100%     268,505  154,486
# 4      Butler   Trump +24  R+27.6                100%     200,623        0
# 5      Lorain    Trump +2   D+0.1                100%     189,879   88,884
# 6      Warren   Trump +31  R+37.1                100%     186,737   82,258
# 7        Lake   Trump +14  R+15.2                100%     157,437        0
# 8    Delaware    Trump +7  R+15.8                100%     136,100   67,800
# 9    Mahoning  Trump +1.9   D+3.2                100%     130,509        0

# %%
df = pd.read_csv("Countyvotestidied.csv")
df.tail(10)
# Out:
#     Cuyahoga  Biden +34  D+35.2 Est. votes reported Total votes Absentee
# 75      Pike  Trump +49  R+36.5                100%      12,947        0
# 76     Adams  Trump +64  R+55.5                100%      12,612        0
# 77   Wyandot  Trump +50  R+46.6                100%      12,412    6,386
# 78     Meigs  Trump +53  R+50.3                100%      12,145    5,735
# 79  Paulding  Trump +51  R+48.5                100%      11,390        0
# 80  Harrison  Trump +53    R+48                100%      10,951        0
# 81    Monroe  Trump +54  R+46.8                100%       9,467        0
# 82    Morgan  Trump +48  R+41.6                100%       7,655        0
# 83     Noble  Trump +63  R+55.1                100%       7,148        0
# 84    Vinton  Trump +55  R+45.7                100%       6,847        0

# %% [markdown]
# Raw dataset on how young Black Americans view the presidental candidates

# %%
df = pd.read_csv("Howvotersthinkraw.csv")
df.head(10)
# Out:
#                              Views on the candidates Unnamed: 1
# 0      Have anything positive to say about Joe Biden        NaN
# 1                                                NaN        46%
# 2  Plan to vote for Joe Biden in the general elec...        NaN
# 3                                                47%        47%
# 4   Have anything positive to say about Donald Trump        NaN
# 5                                                 5%         5%
# 6  Plan to vote for Donald Trump in the general e...        NaN
# 7                                                 8%         8%
# 8                                       Voting plans        NaN
# 9  Trust their state to report their vote accurately        NaN

# %% [markdown]
# https://docs.google.com/spreadsheets/d/1RTSPmV6z0I5pF2t4KZs6WDYn4piMdMhFyVJ9k55n4us/edit#gid=0

# %%
df = pd.read_csv("Howvotersthinkraw.csv")
df.tail(10)
# Out:
#                               Views on the candidates Unnamed: 1
# 20  Say the Republican Party is welcoming to Black...        NaN
# 21                                                28%        28%
# 22  View the Democratic Party as more welcoming th...        NaN
# 23                                                51%        51%
# 24  Trust Democrats in Congress to do what's best ...        NaN
# 25                                                44%        44%
# 26  Trust Republicans in Congress to do what's bes...        NaN
# 27                                                29%        29%
# 28  Trust Democrats more than Republicans to do wh...        NaN
# 29                                                48%        48%

# %%
df.shape
# Out:
# (30, 2)

# %%
df = pd.read_csv("Howvotersthinktidied.csv")
df.head(10)
# Out:
#                              Views on the candidates
# 0      Have anything positive to say about Joe Biden
# 1                                                46%
# 2  Plan to vote for Joe Biden in the general elec...
# 3                                                47%
# 4   Have anything positive to say about Donald Trump
# 5                                                 5%
# 6  Plan to vote for Donald Trump in the general e...
# 7                                                 8%
# 8                                       Voting plans
# 9  Trust their state to report their vote accurately

# %%
df = pd.read_csv("Howvotersthinktidied.csv")
df.tail(10)
# Out:
#                               Views on the candidates
# 20  Say the Republican Party is welcoming to Black...
# 21                                                28%
# 22  View the Democratic Party as more welcoming th...
# 23                                                51%
# 24  Trust Democrats in Congress to do what's best ...
# 25                                                44%
# 26  Trust Republicans in Congress to do what's bes...
# 27                                                29%
# 28  Trust Democrats more than Republicans to do wh...
# 29                                                48%

# %%
df.shape
# Out:
# (30, 1)

# %% [markdown]
# https://docs.google.com/spreadsheets/d/1RTSPmV6z0I5pF2t4KZs6WDYn4piMdMhFyVJ9k55n4us/edit#gid=0
